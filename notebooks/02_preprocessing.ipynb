# %% [markdown]
# 목적: 데이터 전처리
# 내용:
# - 결측치 처리
# - 공백 제거
# - 카테고리 분류 (업종 단순화)
# - 소재지 통일
# - CSV 저장

# %%
import pandas as pd

# %%
df1 = pd.read_csv('../가맹점_현황.csv')
df2 = pd.read_csv('../판매_현황.csv')
df3 = pd.read_csv('../회수_현황.csv')

# %%
# 결측치 탐색
df1.isnull().sum()
# Out:
# 가맹점명               40
# 소속 시장명(또는 상점가)      0
# 소재지                 0
# 취급품목              293
# 지류형 가맹 여부           0
# 디지털형 가맹 여부          0
# 등록년도                0
# dtype: int64

# %%
df1[df1['소재지'] == '광주']
# Out:
#                가맹점명                소속 시장명(또는 상점가) 소재지     취급품목 지류형 가맹 여부  \
# 1           못난이 꽈배기  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주  꽈배기 도너츠         Y
# 2            일곡열쇠철물  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주       열쇠         Y
# 4             뿔라헤어컷  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주       미용         Y
# 7               투다리                    호남동 골목형상점가  광주     꼬치구이         Y
# 8       보이스&보컬 스튜디오                 장원초 입구 골목형상점가  광주    발성 교정         Y
# ...             ...                           ...  ..      ...       ...
# 148524         시장통닭                          월곡시장  광주        닭         Y
# 148525        언니네반찬                          월곡시장  광주       김치         Y
# 148526         한일수산                          월곡시장  광주       홍어         Y
# 148527         송죽식품                          월곡시장  광주       식품         Y
# 148528         싱싱야채                          월곡시장  광주       야채         Y
#
#        디지털형 가맹 여부  등록년도
# 1               Y  2025
# 2               Y  2025
# 4               Y  2025
# 7               Y  2025
# 8               Y  2025
# ...           ...   ...
# 148524          Y  2010
# 148525          Y  2010
# 148526          Y  2010
# 148527          Y  2010
# 148528          Y  2010
#
# [14399 rows x 7 columns]

# %%
df2.isnull().sum()
# Out:
# 구분                0
# 2015년_판매금액(억원)    0
# 2016년_판매금액(억원)    0
# 2017년_판매금액(억원)    0
# 2018년_판매금액(억원)    0
# 2019년_판매금액(억원)    0
# 2020년_판매금액(억원)    0
# 2021년_판매금액(억원)    0
# 2022년_판매금액(억원)    0
# 2023년_판매금액(억원)    0
# 2024년_판매금액(억원)    0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# 구분                0
# 2015년_회수금액(억원)    0
# 2016년_회수금액(억원)    0
# 2017년_회수금액(억원)    0
# 2018년_회수금액(억원)    0
# 2019년_회수금액(억원)    0
# 2020년_회수금액(억원)    0
# 2021년_회수금액(억원)    0
# 2022년_회수금액(억원)    0
# 2023년_회수금액(억원)    0
# 2024년_회수금액(억원)    0
# dtype: int64

# %%
# 결측치 처리
df1 = df1.dropna(subset=['가맹점명'], ignore_index=True)
df1['취급품목'] = df1['취급품목'].fillna('미분류')

# %%
# 결측치 제거 후 데이터 
df1.shape
# Out:
# (150501, 7)

# %%
# 각 컬럼에 어떤 값들이 들어있는지 확인 (이게 이상치 탐색을 대신함)
# 수치적 이상치 제거는 하지 않는다. 대신 데이터의 형식을 맞추는 '표준화'에 집중한다.
df1['소재지'].unique()
# Out:
# array(['경기', '광주', '충남', '전북', '충북', '전남', '서울', '제주', '경남', '대전', '인천',
#        '부산', '강원', '울산', '세종', '대구', '경북'], dtype=object)

# %%
df1['가맹점명'].unique()
# Out:
# array(['초마맨1981', '못난이 꽈배기', '일곡열쇠철물', ..., '파마미용실', '두메하누', '단양보리밥'],
#       dtype=object)

# %%
print(df1['지류형 가맹 여부'].unique())
print(df1['디지털형 가맹 여부'].unique())
# Out:
# ['Y']
# ['Y' 'N']

# %%
# 결측치 이상치 이상치 없는 .가맹점_현황.csv 저장
cleaned_onnuri.to_csv('df1', index=False, encoding='utf-8-sig')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 2
#       1 # 결측치 이상치 이상치 없는 .가맹점_현황.csv 저장
# ----> 2 cleaned_onnuri.to_csv('df1', index=False, encoding='utf-8-sig')
#
# NameError: name 'cleaned_onnuri' is not defined

# %%
df2['구분'].unique()
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
df3['구분'].unique()
# Out:
# array(['서울', '부산', '대구', '인천', '광주', '대전', '울산', '세종', '경기', '강원', '충북',
#        '충남', '전북', '전남', '경북', '경남', '제주'], dtype=object)

# %%
# 로직
