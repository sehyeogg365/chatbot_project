# %% [markdown]
# 목적: 데이터 이해하기
# 내용:
# - CSV 로드
# - 기본 통계 (shape, dtypes, describe)
# - 결측치 확인
# - 샘플 데이터 확인
# - 간단한 시각화 (지역별 분포 등)
#
# 소요: 1-2시간

# %%
# 챗봇 프로젝트
import pandas as pd
import sqlite3

# %%
df1 = pd.read_csv('../가맹점_현황.csv')
df1.head()
# Out:
#       가맹점명                소속 시장명(또는 상점가) 소재지        취급품목 지류형 가맹 여부 디지털형 가맹 여부  \
# 0  초마맨1981                     권율 골목형상점가  경기  짜장면 짬뽕 탕수육         Y          Y
# 1  못난이 꽈배기  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주     꽈배기 도너츠         Y          Y
# 2   일곡열쇠철물  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주          열쇠         Y          Y
# 3   참새 방앗간                     권율 골목형상점가  경기      육전 새우전         Y          Y
# 4    뿔라헤어컷  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주          미용         Y          Y
#
#    등록년도
# 0  2025
# 1  2025
# 2  2025
# 3  2025
# 4  2025

# %%
df1.shape
df1.dtypes
df1.describe
# Out:
# <bound method NDFrame.describe of            가맹점명                소속 시장명(또는 상점가) 소재지        취급품목 지류형 가맹 여부  \
# 0       초마맨1981                     권율 골목형상점가  경기  짜장면 짬뽕 탕수육         Y
# 1       못난이 꽈배기  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주     꽈배기 도너츠         Y
# 2        일곡열쇠철물  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주          열쇠         Y
# 3        참새 방앗간                     권율 골목형상점가  경기      육전 새우전         Y
# 4         뿔라헤어컷  일곡동(제4지역:쌍용,호반,청솔2,호반일신,청솔1)  광주          미용         Y
# ...         ...                           ...  ..         ...       ...
# 150536     태성마트                단양구경시장(단양인정시장)  충북          식잡         Y
# 150537     동산닭집                단양구경시장(단양인정시장)  충북     일반한식,생닭         Y
# 150538    파마미용실                단양구경시장(단양인정시장)  충북       일반미용업         Y
# 150539     두메하누                단양구경시장(단양인정시장)  충북        한식점업         Y
# 150540    단양보리밥                단양구경시장(단양인정시장)  충북          분식         Y
#
#        디지털형 가맹 여부  등록년도
# 0               Y  2025
# ...

# %%
df2 = pd.read_csv('../판매_현황.csv')
df2.head()
# Out:
#    구분  2015년_판매금액(억원)  2016년_판매금액(억원)  2017년_판매금액(억원)  2018년_판매금액(억원)  \
# 0  서울          1968.9          2500.6          2064.6          2884.2
# 1  부산          1022.8          1260.6          1658.8          2117.5
# 2  대구           678.5           897.9          1166.4          1578.5
# 3  인천           286.0           439.1           438.7           634.9
# 4  광주           267.1           375.3           467.2           681.3
#
#    2019년_판매금액(억원)  2020년_판매금액(억원)  2021년_판매금액(억원)  2022년_판매금액(억원)  \
# 0          3327.9          7183.3          5058.3          3903.4
# 1          2592.8          5910.1          4506.9          3928.8
# 2          1842.8          5684.2          3606.4          2868.3
# 3           639.7          1582.1          1164.6           750.8
# 4           716.9          1368.5           904.3           728.0
#
#    2023년_판매금액(억원)  2024년_판매금액(억원)
# 0          4536.2          5201.1
# 1          3763.3          5262.0
# 2          2856.8          3584.0
# ...

# %%
df2.shape
df2.dtypes
df2.describe
# Out:
# <bound method NDFrame.describe of     구분  2015년_판매금액(억원)  2016년_판매금액(억원)  2017년_판매금액(억원)  2018년_판매금액(억원)  \
# 0   서울          1968.9          2500.6          2064.6          2884.2
# 1   부산          1022.8          1260.6          1658.8          2117.5
# 2   대구           678.5           897.9          1166.4          1578.5
# 3   인천           286.0           439.1           438.7           634.9
# 4   광주           267.1           375.3           467.2           681.3
# 5   대전           255.5           271.8           299.1           379.7
# 6   울산           349.4           765.6           460.9           730.5
# 7   세종            34.5            32.6            33.7            50.2
# 8   경기          1013.6          1286.6          1030.1          1582.5
# 9   강원           211.6           241.5           235.8           153.2
# 10  충북           130.7           132.5           126.2           192.8
# 11  충남           179.4           179.1           173.3           272.0
# ...

# %%
df3 = pd.read_csv('../회수_현황.csv')
df3.head()
# Out:
#    구분  2015년_회수금액(억원)  2016년_회수금액(억원)  2017년_회수금액(억원)  2018년_회수금액(억원)  \
# 0  서울          1460.6          2131.7          2257.8          2889.8
# 1  부산          1147.0          1647.9          1916.3          2454.1
# 2  대구           844.8          1246.4          1520.2          2013.8
# 3  인천           344.7           498.6           491.3           606.9
# 4  광주           309.7           444.5           569.6           800.3
#
#    2019년_회수금액(억원)  2020년_회수금액(억원)  2021년_회수금액(억원)  2022년_회수금액(억원)  \
# 0          3449.0          6806.3          7281.2          6194.1
# 1          2909.2          5808.0          5606.2          4010.3
# 2          2332.8          6066.5          5812.6          4460.2
# 3           632.8          1352.6          1143.0           752.4
# 4           857.0          1331.2          1282.3           835.1
#
#    2023년_회수금액(억원)  2024년_회수금액(억원)
# 0          7288.1          9361.5
# 1          5038.3          5475.8
# 2          5536.2          8124.6
# ...

# %%
df3.shape
df3.dtypes
df3.describe
# Out:
# <bound method NDFrame.describe of     구분  2015년_회수금액(억원)  2016년_회수금액(억원)  2017년_회수금액(억원)  2018년_회수금액(억원)  \
# 0   서울          1460.6          2131.7          2257.8          2889.8
# 1   부산          1147.0          1647.9          1916.3          2454.1
# 2   대구           844.8          1246.4          1520.2          2013.8
# 3   인천           344.7           498.6           491.3           606.9
# 4   광주           309.7           444.5           569.6           800.3
# 5   대전           209.5           256.4           240.0           325.3
# 6   울산           286.1           463.6           386.4           576.1
# 7   세종            37.8            16.6            14.6            19.3
# 8   경기           758.3          1056.0           885.9          1134.8
# 9   강원           145.3           172.3           161.8           174.8
# 10  충북           160.7           161.7           146.1           187.0
# 11  충남           184.5           270.5           227.6           294.4
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_11856\716265172.py in ?()
# ----> 1 df1.isunll().sum()
#
# c:\Users\USER\miniconda3\envs\sesac\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6317             and name not in self._accessors
#    6318             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6319         ):
#    6320             return self[name]
# -> 6321         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'isunll'
